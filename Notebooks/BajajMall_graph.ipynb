# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import re
from pprint import pprint
import networkx as nx
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity

# %%
Graphtype = nx.DiGraph()
filepath = '/content/drive/MyDrive/GNN_datasets/edgelist.txt'
G = nx.read_edgelist(
    filepath,
    comments='#',
    create_using=Graphtype,
    nodetype=int
)

# %%
df = pd.read_csv('/content/drive/MyDrive/GNN_datasets/Bajaj Mall Data - Sheet1.csv')

# %%
df
# Out:
#     ID                                               NAME    CATEGORY  PRICE  \
# 0    0  Nilkamal Arthur Double Bed Without Storage (Wa...        Beds  13999
# 1    1  Apka Interior Metallic Sofa cum Bed with Cushi...        Beds  21920
# 2    2  Springtek Folding Sofa Cum Bed - Perfect for G...        Beds   8999
# 3    3  Aaram by Zebrs Wooden King Size Bed Without St...        Beds  31588
# 4    4  Hometown Optimas King Bed With Box Storage (Da...        Beds  20368
# 5    5  @home by Nilkamal Nimbo Queen Bed Without Stor...        Beds   9975
# 6    6  @home by Nilkamal Theia High Gloss King Bed wi...        Beds  69900
# 7    7  Whirlpool 265 L 2 Star Frost Free Double Door ...      Fridge  26500
# 8    8  Haier 195 L 3 Star Direct Cool Single Door Ref...      Fridge  13499
# 9    9  LG 190 L 3 Star Direct Cool Single Door Refrig...      Fridge  20699
# 10  10  Samsung 198 L 5 Star Direct Cool Single Door R...      Fridge  21600
# ...

# %%
df['CATEGORY'].value_counts()
# Out:
# Fridge        8
# Laptop        8
# Beds          7
# Smartphone    7
# Name: CATEGORY, dtype: int64

# %%
df = df.set_index('ID')

# %%
nodeattrdf = df[['NAME','CATEGORY', 'PRICE', 'AVGRATING']].copy()

# %%
nx.set_node_attributes(G, nodeattrdf.to_dict('index'))

# %%
G.nodes[8]
# Out:
# {'NAME': 'Haier 195 L 3 Star Direct Cool Single Door Refrigerator Black Brushline (HRD-1953CKS-E)',
#  'CATEGORY': 'Fridge',
#  'PRICE': 13499,
#  'AVGRATING': 2.1}

# %%
remove = [nodes for nodes in dict(G.nodes()) if len(G.nodes[nodes]) == 0]

# %%
G.remove_nodes_from(remove)

# %%
remove
# Out:
# []
